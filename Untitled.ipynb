# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
im = cv2.imread('./train/color/0.png')
gt = cv2.imread('./train/normal/0.png')
msk = cv2.imread('./train/mask/0.png')

# %%
# cv2.imshow('image',im)
print(gt.shape)
print(msk.shape)
# print(msk[:,:,0] == msk[:,:,2])
# Out:
# (128, 128, 3)
# (128, 128, 3)
# [[ True  True  True ...  True  True  True]
#  [ True  True  True ...  True  True  True]
#  [ True  True  True ...  True  True  True]
#  ...
#  [ True  True  True ...  True  True  True]
#  [ True  True  True ...  True  True  True]
#  [ True  True  True ...  True  True  True]]

# %%
plt.imshow(gt)
# gt
# Out:
# array([[[244, 178, 125],
#         [244, 178, 125],
#         [244, 179, 125],
#         ...,
#         [244, 178, 125],
#         [244, 178, 125],
#         [244, 179, 125]],
#
#        [[244, 179, 125],
#         [244, 179, 125],
#         [244, 179, 125],
#         ...,
#         [243, 179, 125],
#         [244, 179, 125],
#         [243, 179, 125]],
#
#        [[243, 179, 125],
#         [244, 179, 125],
#         [243, 179, 125],
#         ...,
#         [243, 179, 125],
#         [244, 179, 125],
#         [244, 179, 125]],
#
#        ...,
#
#        [[244, 179, 125],
#         [244, 178, 125],
#         [244, 179, 125],
#         ...,
#         [244, 179, 125],
#         [243, 179, 125],
#         [243, 179, 125]],
#
#        [[244, 179, 125],
#         [244, 179, 125],
#         [243, 179, 125],
#         ...,
#         [244, 179, 125],
#         [244, 179, 125],
#         [244, 179, 125]],
#
#        [[244, 179, 125],
#         [244, 179, 125],
#         [244, 179, 125],
#         ...,
#         [244, 179, 125],
#         [244, 179, 125],
#         [243, 179, 125]]], dtype=uint8)

# %%
import tensorflow as tf
import imageio
import os
import numpy as np
import random
from PIL import Image
import glob

# %%
def readimage(folder, index):
    path = os.path.join(folder, str(index)+'.png')
    image = imageio.imread(path)
    return image

def readmask(folder, index):
    path = os.path.join(folder, str(index)+'.png')
    image = imageio.imread(path)
    return image

def readnormal(folder, index):
    path = os.path.join(folder, str(index)+'.png')
    image = imageio.imread(path)
    return image

# %%
# import tensorflow as tf

def weight_variable(shape):
    """
    init the weight variables with truncated normal distribution
    """
    initial = tf.truncated_normal(shape,stddev=0.1)
    return tf.Variable(initial)

def bias_variable(shape):
    """
    init the bias term with constant
    """
    initial = tf.constant(0.1,shape=shape)
    return tf.Variable(initial)

def conv2d(x,w):
    """
    perfrom 2-d convolution
    
    inputs: x (h x w x in_depth)
    weights: w (kernel_size x kernel_size x in_depth x num_filters)
    
    return: output(h x w x num_filters)
    """
    return tf.nn.conv2d(x,w,strides=[1,1,1,1], padding = 'SAME')

def hourglass(inputs, in_dim, out_dim, inter_dim, conv1_size, conv2_size, conv3_size, conv4_size):
    """
    a particular layer of the hourglass architecture mensioned in the papaer
    inputs: example h x w x 128
    in_dim: input dimsion
    out_dim: output dimsion
    inter_dim: interim dimsion
    conv1_size: kernel size of the convolution layer 1, usually is square
    conv2_size: kernel size of the convolution layer 2
    conv3_size, conv4_size: the same as above
    The 1x1 conv before entering into the conv2, conv3, conv4 as mensioned in the papaer
    """
    w02 = weight_variable([1,1,in_dim,inter_dim])
    b02 = bias_variable([inter_dim])
    conv02 = tf.nn.relu(conv2d(inputs, w02) + b02)
    
    w03 = weight_variable([1,1,in_dim,inter_dim])
    b03 = bias_variable([inter_dim])
    conv03 = tf.nn.relu(conv2d(inputs, w03) + b03)
    
    w04 = weight_variable([1,1,in_dim,inter_dim])
    b04 = bias_variable([inter_dim])
    conv04 = tf.nn.relu(conv2d(inputs, w04) + b04)

    w1 = weight_variable([conv1_size,conv1_size,in_dim,out_dim//4])
    b1 = bias_variable([out_dim//4])
    conv1 = tf.nn.relu(conv2d(inputs,w1) + b1)   
    
    w2 = weight_variable([conv2_size,conv2_size,inter_dim,out_dim//4])
    b2 = bias_variable([out_dim//4])
    conv2 = tf.nn.relu(conv2d(conv02,w2) + b2)
    
    w3 = weight_variable([conv3_size,conv3_size,inter_dim, out_dim//4])
    b3 = bias_variable([out_dim//4])
    conv3 = tf.nn.relu(conv2d(conv03,w3) + b3)
    
    w4 = weight_variable([conv4_size,conv4_size,inter_dim, out_dim//4])
    b4 = bias_variable([out_dim//4])
    conv4 = tf.nn.relu(conv2d(conv04,w4) + b4)
    
    res = tf.concat([conv1, conv2, conv3, conv4], axis=3)
    res.shape
    
    return res

# %%
def buildModel(x):
    """
    build the hourglass net model
    x: inputs
    return: outputs of the model 128 x 128 x 3
    """
    wh0 = weight_variable([3,3,3,128])
    bh0 = bias_variable([128])
    convH = tf.nn.relu(conv2d(x, wh0) + bh0)
    #print(convH.shape) # 128 x 128 x 3 -> 128 x 128 x 128
    #
    convA = hourglass(convH,128,64,64,1,3,7,11)
    #print(convA.shape) # 128 x 128 x 64
    [dummybatch,height4,width4,depth4] = convA.shape
    #
    #
    convB_1 = hourglass(convH,128,128,32,1,3,5,7)
    convB_2 = hourglass(convB_1,128,128,32,1,3,5,7)
    #
    ##
    convB_3 = hourglass(convB_2,128,128,32,1,3,5,7)
    convC = hourglass(convB_3,128,128,64,1,3,7,11)
    #print(convC.shape) # 128 x 128 x 128
    [dummybatch,height3,width3,depth3] = convC.shape
    ##
    ##
    convB_maxpool = tf.nn.max_pool(convB_2, ksize=[1,2,2,1], strides=[1,2,2,1],padding = 'SAME')
    convB_4 = hourglass(convB_maxpool,128,128,32,1,3,5,7)
    convD = hourglass(convB_4,128,256,32,1,3,5,7)
    ##
    ###
    convE = hourglass(convD,256,256,32,1,3,5,7) 
    convF = hourglass(convE,256,256,64,1,3,7,11)
    #print(convF.shape) # 64 x 64 x 256
    [dummybatch,height2,width2,depth2] = convF.shape
    ###
    ###
    convD_maxpool = tf.nn.max_pool(convD, ksize=[1,2,2,1], strides=[1,2,2,1],padding='SAME')
    convE_2 = hourglass(convD_maxpool,256,256,32,1,3,5,7)
    convE_3 = hourglass(convE_2,256,256,32,1,3,5,7)
    ###
    ####
    convE_4 = hourglass(convE_3,256,256,32,1,3,5,7)
    convE_5 = hourglass(convE_4,256,256,32,1,3,5,7)
    #print(convE_5.shape)
    [dummybatch,height,width,depth] = convE_5.shape
    ####
    ####
    convE_3_maxpool = tf.nn.max_pool(convE_3,ksize=[1,2,2,1],strides=[1,2,2,1],padding='SAME')
    convE_6 = hourglass(convE_3_maxpool,256,256,32,1,3,5,7)
    convE_7 = hourglass(convE_6,256,256,32,1,3,5,7)
    convE_8 = hourglass(convE_7,256,256,32,1,3,5,7)
    #print(convE_8.shape)
    ####
    ####
    upsample_4 = tf.image.resize_nearest_neighbor(convE_8,[height,width])
    convE_9 = tf.add(upsample_4,convE_5)
    #print(convE_9.shape)
    ####
    ###
    convE_10 = hourglass(convE_9,256,256,32,1,3,5,7)
    convF_2 = hourglass(convE_10,256,256,64,1,3,7,11)
    upsample_3 = tf.image.resize_nearest_neighbor(convF_2,[height2,width2])
    convF_3 = tf.add(upsample_3,convF)
    #print(convF_3.shape)
    ###
    ##
    convE_11 = hourglass(convF_3,256,256,32,1,3,5,7)
    convG = hourglass(convE_11,256,128,32,1,3,5,7)
    upsample_2 = tf.image.resize_nearest_neighbor(convG,[height3,width3])
    convG_2 = tf.add(upsample_2,convC)
    #print(convG_2.shape)
    convB_5 = hourglass(convG_2,128,128,32,1,3,5,7)
    convA_2 = hourglass(convB_5,128,64,64,1,3,7,11)
    ##
    #
    upsample_1 = tf.image.resize_nearest_neighbor(convA_2,[height4,width4])
    convA_3 = tf.add(upsample_1,convA)
    #print(convA_3.shape)
    #
    wh1 = weight_variable([3,3,64,3])
    bh1 = bias_variable([3])
    convH_2 = tf.nn.relu(conv2d(convA_3, wh1) + bh1)
    #print(convH_2.shape)
    return convH_2

# %%
def train_test_split(random_indexes,validation_size):
    train_indexes = random_indexes[:len(random_indexes)-validation_size]
    test_indexes = random_indexes[len(random_indexes)-validation_size:]
    return train_indexes, test_indexes

def get_batches(random_indexes, batch_size):
    num_batches = 20000 // batch_size
    indexes = random_indexes[:num_batches*batch_size]
    for idx in range(0, len(indexes),batch_size):
        yield indexes[idx:idx+batch_size]

# %%
import random

data_size = 20000
epochs = 5
data = [i for i in range(data_size)]
random.shuffle(data)
train, test = train_test_split(data,data_size//10)

# %%
from __future__ import print_function

import argparse
import os
import imageio
import numpy as np


def scan_png_files(folder):
    '''
    folder: 1.png 3.png 4.png 6.png 7.exr unknown.mpeg
    return: ['1.png', '3.png', '4.png']
    '''
    ext = '.png'
    ret = [fname for fname in os.listdir(folder) if fname.endswith(ext)]

    return ret


def evaluate(prediction_folder, groundtruth_folder, mask_folder):
    '''
    Evaluate mean angle error of predictions in the prediction folder,
    given the groundtruth and mask images.
    '''
    # Scan folders to obtain png files
    if mask_folder is None:
        mask_folder = os.path.join(groundtruth_folder, '..', 'mask')

    pred_pngs = scan_png_files(prediction_folder)
    gt_pngs = scan_png_files(groundtruth_folder)
    mask_pngs = scan_png_files(mask_folder)

    pred_diff_gt = set(pred_pngs).difference(gt_pngs)
    assert len(pred_diff_gt) == 0, \
        'No corresponding groundtruth file for the following files:\n' + '\n'.join(pred_diff_gt)
    pred_diff_mask = set(pred_pngs).difference(mask_pngs)
    assert len(pred_diff_mask) == 0, \
        'No corresponding mask file for the following files:\n' + '\n'.join(pred_diff_mask)

    # Measure: mean angle error over all pixels
    mean_angle_error = 0
    total_pixels = 0
    for fname in pred_pngs:
        # print('Proccessing file {}'.format(fname))
        prediction = imageio.imread(os.path.join(prediction_folder, fname))
        groundtruth = imageio.imread(os.path.join(groundtruth_folder, fname))
        mask = imageio.imread(os.path.join(mask_folder, fname)) # Greyscale image

        prediction = ((prediction / 255.0) - 0.5) * 2
        groundtruth = ((groundtruth / 255.0) - 0.5) * 2

        total_pixels += np.count_nonzero(mask)
        mask = mask != 0

        a11 = np.sum(prediction * prediction, axis=2)[mask]
        a22 = np.sum(groundtruth * groundtruth, axis=2)[mask]
        a12 = np.sum(prediction * groundtruth, axis=2)[mask]

        cos_dist = a12 / np.sqrt(a11 * a22)
        cos_dist[np.isnan(cos_dist)] = -1
        cos_dist = np.clip(cos_dist, -1, 1)
        angle_error = np.arccos(cos_dist)
        mean_angle_error += np.sum(angle_error)

    return mean_angle_error / total_pixels

# %%
batch_size = 8
train_color = np.zeros(shape = (batch_size,128,128,3), dtype = 'float32')
train_mask = np.zeros(shape = (batch_size,128,128,3), dtype = 'float32')
train_normal = np.zeros(shape = (batch_size,128,128,3), dtype = 'float32')

validation_color = np.zeros(shape = (len(test),128,128,3), dtype = 'float32')
validation_mask = np.zeros(shape = (len(test),128,128,3), dtype = 'float32')
validation_normal = np.zeros(shape = (len(test),128,128,3), dtype = 'float32')

x = tf.placeholder('float32',[None, 128,128,3]) # color
y = tf.placeholder('float32',[None, 128,128,3]) # mask
z = tf.placeholder('float32',[None, 128,128,3]) # normal

convH_2 = buildModel(x)

prediction = convH_2/255.0
norm = z/255.0
loss = 0

prediction = prediction*y
norm = norm*y
for _ in range(batch_size):
    loss+= 1/batch_size*tf.norm(prediction[_,:,:,:]-norm[_,:,:,:])

opt = tf.train.AdamOptimizer(1e-4).minimize(loss)

# %%
import random

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for e in range(1,epochs+1):
        num_batches = 0
        for batch_index in get_batches(train,batch_size):
            counter = 0
            for i in batch_index:
                train_color[counter,:,:,:] = readimage('./train/color', i)
                train_mask[counter,:,:,0] = readmask('./train/mask', i)
                train_mask[counter,:,:,1] = readmask('./train/mask', i)
                train_mask[counter,:,:,2] = readmask('./train/mask', i)
                train_normal[counter,:,:,:] = readimage('./train/normal', i)
                counter += 1
            
            _, c = sess.run([opt, loss], feed_dict={x: train_color, y: train_mask, z: train_normal})
            num_batches += 1
            print('Epoch {}/{};'.format(e,epochs),'Batches {}/{};'.format(num_batches,len(train)//batch_size),\
                  'Training loss: {:.3f}'.format(c/batch_size))
            
            if num_batches % 2 == 0:
                print("evaluation after 10's batches...\n")         
                # num_test = len(glob.glob('./test/color/*.png'))
                test_color = np.zeros(shape = (1,128,128,3), dtype = 'float32')
                test_mask = np.zeros(shape = (1,128,128,3), dtype = 'float32')
                for k in test:
                    test_color[0,:,:,:] = readimage('./train/color', k)
                    test_mask[0,:,:,0] = readmask('./train/mask', k)
                    test_mask[0,:,:,1] = readmask('./train/mask', k)
                    test_mask[0,:,:,2] = readmask('./train/mask', k)
                    result = sess.run(prediction, feed_dict = {x: test_color, y:test_mask})
                    image=Image.fromarray(result.astype(np.uint8)[0])
                    image.save('./train/pred/'+str(k)+'.png','png')
                evaluate('./train/pred/', './train/color/', './train/mask/')
# Out:
# Epoch 1/5; Batches 1/2250;	 Training loss: 138967.406
# Epoch 1/5; Batches 2/2250;	 Training loss: 205381.469
# evaluation after 10's batches...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-ada925aeb773> in <module>()
#      29                     test_mask[0,:,:,1] = readmask('./train/mask', k)
#      30                     test_mask[0,:,:,2] = readmask('./train/mask', k)
# ---> 31                     result = sess.run(prediction, feed_dict = {x: test_color, y:test_mask})
#      32                     image=Image.fromarray(result.astype(np.uint8)[0])
#      33                     image.save('./train/pred/'+str(k)+'.png','png')
#
# D:\Users\egbertcw\conda3\envs\tf10\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# D:\Users\egbertcw\conda3\envs\tf10\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1126     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1127       results = self._do_run(handle, final_targets, final_fetches,
# -> 1128                              feed_dict_tensor, options, run_metadata)
#    1129     else:
#    1130       results = []
#
# D:\Users\egbertcw\conda3\envs\tf10\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1342     if handle is None:
#    1343       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1344                            options, run_metadata)
#    1345     else:
#    1346       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# D:\Users\egbertcw\conda3\envs\tf10\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1348   def _do_call(self, fn, *args):
#    1349     try:
# -> 1350       return fn(*args)
#    1351     except errors.OpError as e:
#    1352       message = compat.as_text(e.message)
#
# D:\Users\egbertcw\conda3\envs\tf10\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1327           return tf_session.TF_Run(session, options,
#    1328                                    feed_dict, fetch_list, target_list,
# -> 1329                                    status, run_metadata)
#    1330
#    1331     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
evaluate('./train/pred/', './train/color/', './train/mask/')
# Out:
# Proccessing file 10056.png
# Proccessing file 10089.png
# Proccessing file 10258.png
# Proccessing file 10263.png
# Proccessing file 10382.png
# Proccessing file 10446.png
# Proccessing file 10482.png
# Proccessing file 10561.png
# Proccessing file 10592.png
# Proccessing file 1061.png
# Proccessing file 10616.png
# Proccessing file 1065.png
# Proccessing file 10669.png
# Proccessing file 10778.png
# Proccessing file 10832.png
# Proccessing file 10838.png
# Proccessing file 10886.png
# Proccessing file 10895.png
# Proccessing file 10898.png
# Proccessing file 10904.png
# Proccessing file 10977.png
# Proccessing file 10989.png
# Proccessing file 10990.png
# Proccessing file 1110.png
# Proccessing file 11254.png
# Proccessing file 11321.png
# Proccessing file 1139.png
# Proccessing file 11400.png
# Proccessing file 11536.png
# Proccessing file 11538.png
# Proccessing file 1158.png
# Proccessing file 1173.png
# Proccessing file 11752.png
# Proccessing file 11790.png
# Proccessing file 11819.png
# Proccessing file 1182.png
# Proccessing file 11831.png
# Proccessing file 11949.png
# Proccessing file 11965.png
# Proccessing file 11983.png
# Proccessing file 12076.png
# Proccessing file 1214.png
# Proccessing file 12155.png
# Proccessing file 12226.png
# Proccessing file 12351.png
# Proccessing file 12502.png
# Proccessing file 12503.png
# Proccessing file 12535.png
# Proccessing file 12552.png
# Proccessing file 12554.png
# Proccessing file 12557.png
# Proccessing file 12574.png
# Proccessing file 12580.png
# Proccessing file 12652.png
# Proccessing file 12750.png
# Proccessing file 12754.png
# Proccessing file 12882.png
# Proccessing file 12921.png
# Proccessing file 12956.png
# Proccessing file 130.png
# Proccessing file 13023.png
# Proccessing file 1312.png
# Proccessing file 13147.png
# Proccessing file 13159.png
# Proccessing file 13169.png
# Proccessing file 13226.png
# Proccessing file 13266.png
# Proccessing file 13305.png
# Proccessing file 13319.png
# Proccessing file 13352.png
# Proccessing file 1347.png
# Proccessing file 1352.png
# Proccessing file 13578.png
# Proccessing file 1358.png
# Proccessing file 13636.png
# Proccessing file 13661.png
# Proccessing file 13665.png
# Proccessing file 13745.png
# Proccessing file 13821.png
# Proccessing file 1396.png
# Proccessing file 14049.png
# Proccessing file 14056.png
# Proccessing file 14063.png
# Proccessing file 14067.png
# Proccessing file 14119.png
# Proccessing file 14145.png
# Proccessing file 14195.png
# Proccessing file 14196.png
# Proccessing file 14408.png
# Proccessing file 14427.png
# Proccessing file 14477.png
# Proccessing file 1450.png
# Proccessing file 14561.png
# Proccessing file 14589.png
# Proccessing file 14746.png
# Proccessing file 14810.png
# Proccessing file 14811.png
# Proccessing file 1483.png
# Proccessing file 14833.png
# Proccessing file 1484.png
# Proccessing file 14844.png
# Proccessing file 14889.png
# Proccessing file 14966.png
# Proccessing file 14982.png
# Proccessing file 15059.png
# Proccessing file 15153.png
# Proccessing file 15168.png
# Proccessing file 15196.png
# Proccessing file 15294.png
# Proccessing file 15422.png
# Proccessing file 15462.png
# Proccessing file 15476.png
# Proccessing file 15531.png
# Proccessing file 15609.png
# Proccessing file 15668.png
# Proccessing file 1570.png
# Proccessing file 15724.png
# Proccessing file 15779.png
# Proccessing file 15859.png
# Proccessing file 15903.png
# Proccessing file 15908.png
# Proccessing file 15934.png
# Proccessing file 15955.png
# Proccessing file 1598.png
# Proccessing file 16125.png
# Proccessing file 1614.png
# Proccessing file 16288.png
# Proccessing file 16338.png
# Proccessing file 16382.png
# Proccessing file 16387.png
# Proccessing file 16446.png
# Proccessing file 16488.png
# Proccessing file 16540.png
# Proccessing file 16553.png
# Proccessing file 1656.png
# Proccessing file 16591.png
# Proccessing file 16595.png
# Proccessing file 16620.png
# Proccessing file 16646.png
# Proccessing file 16761.png
# Proccessing file 16821.png
# Proccessing file 16840.png
# Proccessing file 16893.png
# Proccessing file 16928.png
# Proccessing file 16934.png
# Proccessing file 1697.png
# Proccessing file 17002.png
# Proccessing file 17101.png
# Proccessing file 17284.png
# Proccessing file 17357.png
# Proccessing file 17416.png
# Proccessing file 17421.png
# Proccessing file 17440.png
# Proccessing file 17515.png
# Proccessing file 17549.png
# Proccessing file 17574.png
# Proccessing file 17587.png
# Proccessing file 1759.png
# Proccessing file 17608.png
# Proccessing file 17652.png
# Proccessing file 1769.png
# Proccessing file 17697.png
# Proccessing file 17749.png
# Proccessing file 17889.png
# Proccessing file 17891.png
# Proccessing file 17922.png
# Proccessing file 17953.png
# Proccessing file 1800.png
# Proccessing file 18003.png
# Proccessing file 18063.png
# Proccessing file 18168.png
# Proccessing file 18175.png
# Proccessing file 18265.png
# Proccessing file 18281.png
# Proccessing file 18309.png
# Proccessing file 18312.png
# Proccessing file 18333.png
# Proccessing file 18395.png
# Proccessing file 18493.png
# Proccessing file 18507.png
# Proccessing file 18567.png
# Proccessing file 18616.png
# Proccessing file 18625.png
# Proccessing file 1867.png
# Proccessing file 1871.png
# Proccessing file 18760.png
# Proccessing file 1880.png
# Proccessing file 18869.png
# Proccessing file 18971.png
# Proccessing file 18986.png
# Proccessing file 19032.png
# Proccessing file 19054.png
# Proccessing file 19107.png
# Proccessing file 19198.png
# Proccessing file 19214.png
# Proccessing file 1924.png
# Proccessing file 19281.png
# Proccessing file 19442.png
# Proccessing file 19458.png
# Proccessing file 19598.png
# Proccessing file 19601.png
# Proccessing file 19628.png
# Proccessing file 19690.png
# Proccessing file 19719.png
# Proccessing file 19720.png
# Proccessing file 198.png
# Proccessing file 19835.png
# Proccessing file 199.png
# Proccessing file 19962.png
# Proccessing file 2030.png
# Proccessing file 2054.png
# Proccessing file 2074.png
# Proccessing file 2139.png
# Proccessing file 2232.png
# Proccessing file 2273.png
# Proccessing file 2285.png
# Proccessing file 2286.png
# Proccessing file 2330.png
# Proccessing file 2345.png
# Proccessing file 241.png
# Proccessing file 2425.png
# Proccessing file 2465.png
# Proccessing file 2515.png
# Proccessing file 2552.png
# Proccessing file 2621.png
# Proccessing file 2640.png
# Proccessing file 2705.png
# Proccessing file 2777.png
# Proccessing file 2781.png
# Proccessing file 2801.png
# Proccessing file 2862.png
# Proccessing file 2863.png
# Proccessing file 2867.png
# Proccessing file 2939.png
# Proccessing file 3028.png
# Proccessing file 3039.png
# Proccessing file 3147.png
# Proccessing file 3267.png
# Proccessing file 3302.png
# Proccessing file 3315.png
# Proccessing file 3365.png
# Proccessing file 3491.png
# Proccessing file 3529.png
# Proccessing file 355.png
# Proccessing file 367.png
# Proccessing file 3693.png
# Proccessing file 377.png
# Proccessing file 3795.png
# Proccessing file 3916.png
# Proccessing file 3918.png
# Proccessing file 3945.png
# Proccessing file 3988.png
# Proccessing file 3997.png
# Proccessing file 4042.png
# Proccessing file 4045.png
# Proccessing file 415.png
# Proccessing file 4198.png
# Proccessing file 4234.png
# Proccessing file 4255.png
# Proccessing file 4286.png
# Proccessing file 4342.png
# Proccessing file 4427.png
# Proccessing file 4428.png
# Proccessing file 443.png
# Proccessing file 4516.png
# Proccessing file 4519.png
# Proccessing file 4543.png
# Proccessing file 4608.png
# Proccessing file 4725.png
# Proccessing file 4726.png
# Proccessing file 4748.png
# Proccessing file 4752.png
# Proccessing file 4904.png
# Proccessing file 4932.png
# Proccessing file 5004.png
# Proccessing file 5007.png
# Proccessing file 501.png
# Proccessing file 5060.png
# Proccessing file 5109.png
# Proccessing file 5125.png
# Proccessing file 514.png
# Proccessing file 5158.png
# Proccessing file 5159.png
# Proccessing file 5161.png
# Proccessing file 5230.png
# Proccessing file 5392.png
# Proccessing file 5410.png
# Proccessing file 546.png
# Proccessing file 5470.png
# Proccessing file 5526.png
# Proccessing file 5531.png
# Proccessing file 572.png
# Proccessing file 5751.png
# Proccessing file 581.png
# Proccessing file 5850.png
# Proccessing file 5865.png
# Proccessing file 5994.png
# Proccessing file 6017.png
# Proccessing file 6045.png
# Proccessing file 6127.png
# Proccessing file 6155.png
# Proccessing file 6371.png
# Proccessing file 6380.png
# Proccessing file 6394.png
# Proccessing file 6416.png
# Proccessing file 6426.png
# Proccessing file 6577.png
# Proccessing file 6587.png
# Proccessing file 6590.png
# Proccessing file 6658.png
# Proccessing file 67.png
# Proccessing file 6731.png
# Proccessing file 6747.png
# Proccessing file 6769.png
# Proccessing file 6788.png
# Proccessing file 6826.png
# Proccessing file 6833.png
# Proccessing file 6848.png
# Proccessing file 6849.png
# Proccessing file 6872.png
# Proccessing file 6901.png
# Proccessing file 6956.png
# Proccessing file 6958.png
# Proccessing file 70.png
# Proccessing file 7215.png
# Proccessing file 7221.png
# Proccessing file 7245.png
# Proccessing file 7415.png
# Proccessing file 7446.png
# Proccessing file 746.png
# Proccessing file 7498.png
# Proccessing file 7520.png
# Proccessing file 7660.png
# Proccessing file 7664.png
# Proccessing file 7685.png
# Proccessing file 7739.png
# Proccessing file 7785.png
# Proccessing file 7856.png
# Proccessing file 8020.png
# Proccessing file 8144.png
# Proccessing file 8237.png
# Proccessing file 8284.png
# Proccessing file 8321.png
# Proccessing file 8324.png
# Proccessing file 8667.png
# Proccessing file 8673.png
# Proccessing file 8692.png
# Proccessing file 8711.png
# Proccessing file 8717.png
# Proccessing file 8800.png
# Proccessing file 8818.png
# Proccessing file 8860.png
# Proccessing file 8861.png
# Proccessing file 8866.png
# Proccessing file 8891.png
# Proccessing file 890.png
# Proccessing file 898.png
# Proccessing file 9080.png
# Proccessing file 9145.png
# Proccessing file 917.png
# Proccessing file 9171.png
# Proccessing file 9255.png
# Proccessing file 9261.png
# Proccessing file 9282.png
# Proccessing file 94.png
# Proccessing file 9417.png
# Proccessing file 9474.png
# Proccessing file 9535.png
# Proccessing file 9557.png
# Proccessing file 9636.png
# Proccessing file 9675.png
# Proccessing file 9692.png
# Proccessing file 9721.png
# Proccessing file 9801.png
# Proccessing file 9803.png
# Proccessing file 9849.png
# Proccessing file 9864.png
# Proccessing file 9872.png
# Proccessing file 9920.png
# Proccessing file 9944.png
# Proccessing file 996.png
# Proccessing file 9974.png
# Proccessing file 9988.png
# 0.3525225673580742
